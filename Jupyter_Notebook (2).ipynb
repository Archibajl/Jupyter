# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# 2 - Create a markdown cell with the title of the notebook.
# <H1> Notebook Title

# %% [markdown]
#  3 - Create a markdown cell for an introduction.
# <H2> Introduction: this is a Jyupyter lab for the final project in the Tools for Data Science course

# %% [markdown]
# <H3>4. DataScience Languages: <br>
# Python, <br>
# R, <br>
# Anaconda

# %% [markdown]
# <H3>5. DataScience Libraries: <br>
# ggplot, <br>
# matPlotLib, <br>
# Sci Kit Learn (SKLearn), <br>
# PyPlot

# %% [markdown]
# <H3>6. table of Data Science tools.

# %% [markdown]
#
# | Languages |                 IDE's                    |          Libraries          |
# |:---------:|:----------------------------------------:|:---------------------------:|
# | Python    | Jupyter-Notebooks, Jupyterlite, Pycharm VS Code, google-Colab   | SKLearn, MatPlotLib, PyPlot |
# |     R     | Jupyter-Notebooks, Jupyterlite, R-Studio, VS Code, google-Colab | ggplot                      |
# | Anaconda  | Same as Python                                                  | same as Python              |
# |:---------:|:----------------------------------------:|:---------------------------:|

# %% [markdown]
# <H3>7. arithmetic expression examples:  <br>
#
#     arithmatic operators <br>
#     * multiplication 3*4  <br>
#     / division 4/2  <br>
#     - subtraction 2-1  <br>
#     + addition 1+2  <br>
#     % modulus (remainder) 3%4  <br>

# %% [markdown]
# <H3> 8.  Create a code cell to multiply and add numbers.

# %%
print("mulltiply numbers 3 & 7")
print(3*7)

print("add nubmers 3 & 7")
print(3+7)
# Out:
# mulltiply numbers 3 & 7
# 21
# add nubmers 3 & 7
# 10

# %% [markdown]
# <H3> 9.Create a code cell to convert minutes to hours

# %%
minutes = 125
print("converting ", minutes, " minutes to hours")
hours = minutes/60
print(minutes, " minutes are", hours, " hours")
# Out:
# converting  125  minutes to hours
# 125  minutes are 2.0833333333333335  hours

# %% [markdown]
# <H3> 10. Insert a markdown cell to list Objectives?
#
#     There are a total of 25 points possible for this final project.
#
# Your grade will be based on the following Exercises:
#
# Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
#
# Exercise 3 - Create a markdown cell for an introduction. (1 pt)
#
# Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
#
# Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
#
# Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
#
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)
#
# Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)
#
# Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
#
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
#
# Exercise 12 - Share your notebook through GitHub (3 pts)
#
# Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)
#
# The main grading criteria will be:
#
# Is the notebook publicly viewable?
#
# Are there, or do there appear to be, at least 8 Markdown cells and 2 code cells?
#
# Are the criteria for each cell fulfilled, as described in the "Guidelines for Submission"?
#
# You will not be judged on:
#
# Your English language, including spelling or grammatical mistakes.
#
# Step-By-Step Assignment Instructions
# less
# Assignment Topic:
#
# You will be provided with an empty Jupyterlite notebook which you will launch in the course, to complete this assignment. You will need to include a combination of markdown and code cells. You will likely need to use the Markdown cheat sheet to help you determine the appropriate syntax for your markdown.
#     Best guess on what that means.

# %% [markdown]
# <H3> 11. Create a markdown cell to indicate the Author’s name <br>
#     Name: Justin Archibald

# %% [markdown]
# <H3> 12. Share your notebook through GitHub
#     ?

# %% [markdown]
# <H3> 13. Take a screenshot of the first page of the notebook <br>

# %% [markdown]
# ![Jupyter-lab 1.png](attachment:5ab8f1af-2b4d-47f3-9a05-9541484657f4.png)
